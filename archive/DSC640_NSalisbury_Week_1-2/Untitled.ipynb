# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
hotdog_winners = pd.read_excel('hotdog-contest-winners.xlsm')

# %%
hotdog_winners.rename(columns={'Dogs eaten':'dogs_eaten','New record':'new_record'},inplace=True)

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(6, 15))

sns.set_color_codes("pastel")
ax = sns.barplot(x='dogs_eaten', y='Year', data=hotdog_winners, color='b', orient='h')

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

ax.set_xlabel("Hot Dogs Eaten")
ax.set_ylabel("Contest Year")
ax.set_title("Hot Dog Eating Contest Winning Numbers")
# Out:
# Text(0.5, 1.0, 'Hot Dog Eating Contest Winning Numbers')

# %%
hotdog_places = pd.read_excel('hotdog-places.xlsm')

# %%
hotdog_places
# Out:
#    2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010
# 0    25  50.0  50.5  44.5  53.5    49    54    66    59  68.0    54
# 1    24  31.0  26.0  30.5  38.0    37    52    63    59  64.5    43
# 2    22  23.5  25.5  29.5  32.0    32    37    49    42  55.0    37

# %%
hotdog_places.rename(index={0: "first", 1: "second", 2: "third"}, inplace=True)

# %%
hotdog_places
# Out:
#         2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010
# first     25  50.0  50.5  44.5  53.5    49    54    66    59  68.0    54
# second    24  31.0  26.0  30.5  38.0    37    52    63    59  64.5    43
# third     22  23.5  25.5  29.5  32.0    32    37    49    42  55.0    37

# %%
hotdog_places = hotdog_places.T

# %%
hotdog_places.reset_index(inplace=True)

# %%
hotdog_places
# Out:
#     index  first  second  third
# 0    2000   25.0    24.0   22.0
# 1    2001   50.0    31.0   23.5
# 2    2002   50.5    26.0   25.5
# 3    2003   44.5    30.5   29.5
# 4    2004   53.5    38.0   32.0
# 5    2005   49.0    37.0   32.0
# 6    2006   54.0    52.0   37.0
# 7    2007   66.0    63.0   49.0
# 8    2008   59.0    59.0   42.0
# 9    2009   68.0    64.5   55.0
# 10   2010   54.0    43.0   37.0

# %%
hotdog_places.rename(columns={"index": "year"}, inplace=True)

# %%
hotdog_places
# Out:
#     year  first  second  third
# 0   2000   25.0    24.0   22.0
# 1   2001   50.0    31.0   23.5
# 2   2002   50.5    26.0   25.5
# 3   2003   44.5    30.5   29.5
# 4   2004   53.5    38.0   32.0
# 5   2005   49.0    37.0   32.0
# 6   2006   54.0    52.0   37.0
# 7   2007   66.0    63.0   49.0
# 8   2008   59.0    59.0   42.0
# 9   2009   68.0    64.5   55.0
# 10  2010   54.0    43.0   37.0

# %%
obama_approval = pd.read_excel('obama-approval-ratings.xls')

# %%
obama_approval
# Out:
#                        Issue  Approve  Disapprove  None
# 0             Race Relations       52          38    10
# 1                  Education       49          40    11
# 2                  Terrorism       48          45     7
# 3              Energy Policy       47          42    11
# 4            Foreign Affairs       44          48     8
# 5                Environment       43          51     6
# 6          Situation in Iraq       41          53     6
# 7                      Taxes       41          54     5
# 8          Healthcare Policy       40          57     3
# 9                    Economy       38          59     3
# 10  Situation in Afghanistan       36          57     7
# 11    Federal Budget Deficit       31          64     5
# 12               Immigration       29          62     9

# %%
obama_approval.columns.tolist()
# Out:
# ['Issue', 'Approve', 'Disapprove', 'None']
